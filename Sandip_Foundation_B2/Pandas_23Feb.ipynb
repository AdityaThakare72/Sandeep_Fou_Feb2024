# %%
import pandas as pd

# %% [markdown]
# ## Series

# %%
s = pd.Series([34,32,56,54,31])

# %%
s
# Out:
# 0    34
# 1    32
# 2    56
# 3    54
# 4    31
# dtype: int64

# %%
s[2]
# Out:
# 56

# %%
s[0] = 49

# %%
s
# Out:
# 0    49
# 1    32
# 2    56
# 3    54
# 4    31
# dtype: int64

# %%
s = pd.Series([34,32,56,54,31], index = range(101,106))

# %%
s
# Out:
# 101    34
# 102    32
# 103    56
# 104    54
# 105    31
# dtype: int64

# %%
s[102]
# Out:
# 32

# %% [markdown]
# ## DataFrame

# %%
roll = [1,2,3,4,5]
name = ['Ajay','Natasha','Riya','Numesh','Jay']
marks = [67,87,68,81,75]

# %%
data = pd.DataFrame({
    'roll': roll,
    'name': name,
    'marks': marks
})

# %%
data
# Out:
#    roll     name  marks
# 0     1     Ajay     67
# 1     2  Natasha     87
# 2     3     Riya     68
# 3     4   Numesh     81
# 4     5      Jay     75

# %%
data.shape
# Out:
# (5, 3)

# %%
data.size
# Out:
# 15

# %%
data.columns
# Out:
# Index(['roll', 'name', 'marks'], dtype='object')

# %%
# https://mitu.co.in/dataset
# download all the files starting from student*
# save to the same directory as jupyter notebook

# %%
df = pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df1 = pd.read_csv('student1.csv')

# %%
df1
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
headers = ['roll', 'name', 'class','marks', 'age']

# %%
df1 = pd.read_csv('student1.csv', names = headers)

# %%
df1
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df2 = pd.read_csv('student3.tsv', sep = '\t')

# %%
df2
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
list(df.columns)
# Out:
# ['roll', 'name', 'class', 'marks', 'age']

# %%
df.T
# Out:
#            0      1       2        3      4       5      6      7      8  \
# roll       1      2       3        4      5       6      7      8      9
# name    anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class     TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks  56.77  59.77   76.88    69.66  63.28   49.55  65.34  68.33  56.75
# age       22     21      19       20     20      20     19     23     20
#
#            9
# roll      10
# name   anmol
# class     BE
# marks  78.66
# age       21

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
df.values
# Out:
# array([[1, 'anil', 'TE', 56.77, 22],
#        [2, 'amit', 'TE', 59.77, 21],
#        [3, 'aniket', 'BE', 76.88, 19],
#        [4, 'ajinkya', 'TE', 69.66, 20],
#        [5, 'asha', 'TE', 63.28, 20],
#        [6, 'ayesha', 'BE', 49.55, 20],
#        [7, 'amar', 'BE', 65.34, 19],
#        [8, 'amita', 'BE', 68.33, 23],
#        [9, 'amol', 'TE', 56.75, 20],
#        [10, 'anmol', 'BE', 78.66, 21]], dtype=object)

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.head(3)
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19

# %%
df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.sum()
# Out:
# roll                                                    55
# name     anilamitaniketajinkyaashaayeshaamaramitaamolanmol
# class                                 TETEBETETEBEBEBETEBE
# marks                                               644.99
# age                                                    205
# dtype: object

# %%
df.min()
# Out:
# roll           1
# name     ajinkya
# class         BE
# marks      49.55
# age           19
# dtype: object

# %%
df.max()
# Out:
# roll         10
# name     ayesha
# class        TE
# marks     78.66
# age          23
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[5:8,:]
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23

# %%
df.iloc[1:4,1]
# Out:
# 1       amit
# 2     aniket
# 3    ajinkya
# Name: name, dtype: object

# %%
df.iloc[5,1]
# Out:
# 'ayesha'

# %%
df.iloc[[3,5,7],:]
# Out:
#    roll     name class  marks  age
# 3     4  ajinkya    TE  69.66   20
# 5     6   ayesha    BE  49.55   20
# 7     8    amita    BE  68.33   23

# %%
df.loc[:,'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[:,['name', 'class']]
# Out:
#       name class
# 0     anil    TE
# 1     amit    TE
# 2   aniket    BE
# 3  ajinkya    TE
# 4     asha    TE
# 5   ayesha    BE
# 6     amar    BE
# 7    amita    BE
# 8     amol    TE
# 9    anmol    BE

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.name
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop(4)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop([3,5,6])
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19
# 4     5    asha    TE  63.28   20
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.drop('class', axis = 1)
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %% [markdown]
# ## Rename

# %%
col = {'roll':'id', 'marks':'grade'}

# %%
df.rename(columns= col)
# rename index => 1 = one, 5 = five
# Out:
#    id     name class  grade  age
# 0   1     anil    TE  56.77   22
# 1   2     amit    TE  59.77   21
# 2   3   aniket    BE  76.88   19
# 3   4  ajinkya    TE  69.66   20
# 4   5     asha    TE  63.28   20
# 5   6   ayesha    BE  49.55   20
# 6   7     amar    BE  65.34   19
# 7   8    amita    BE  68.33   23
# 8   9     amol    TE  56.75   20
# 9  10    anmol    BE  78.66   21

# %%
ind = { 1: 'one', 5: 'five'}

# %%
df.rename(index= ind)
# Out:
#       roll     name class  marks  age
# 0        1     anil    TE  56.77   22
# one      2     amit    TE  59.77   21
# 2        3   aniket    BE  76.88   19
# 3        4  ajinkya    TE  69.66   20
# 4        5     asha    TE  63.28   20
# five     6   ayesha    BE  49.55   20
# 6        7     amar    BE  65.34   19
# 7        8    amita    BE  68.33   23
# 8        9     amol    TE  56.75   20
# 9       10    anmol    BE  78.66   21

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['roll'] = df['roll'] + 100

# %%
df
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106   ayesha    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
gender = ['m','m','m','m','f','f','m','f','m','m']

# %%
df['gender'] = gender

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0   101     anil    TE  56.77   22      m
# 1   102     amit    TE  59.77   21      m
# 2   103   aniket    BE  76.88   19      m
# 3   104  ajinkya    TE  69.66   20      m
# 4   105     asha    TE  63.28   20      f
# 5   106   ayesha    BE  49.55   20      f
# 6   107     amar    BE  65.34   19      m
# 7   108    amita    BE  68.33   23      f
# 8   109     amol    TE  56.75   20      m
# 9   110    anmol    BE  78.66   21      m

# %%
# create a cgpa cloumn which will be marks / 10 + 1.5

df['cgpa'] = df['marks'] / 10 + 1.5

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106   ayesha    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      f  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df['gender'].value_counts()
# Out:
# gender
# m    7
# f    3
# Name: count, dtype: int64

# %%
df['class'].value_counts()
# Out:
# class
# TE    5
# BE    5
# Name: count, dtype: int64

# %%
df['class'].mode()
# Out:
# 0    BE
# 1    TE
# Name: class, dtype: object

# %%
df['class'].mode()[0]
# Out:
# 'BE'

# %% [markdown]
# ## Groupby

# %%
gr = df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('BE')
# Out:
#    roll    name class  marks  age gender   cgpa
# 2   103  aniket    BE  76.88   19      m  9.188
# 5   106  ayesha    BE  49.55   20      f  6.455
# 6   107    amar    BE  65.34   19      m  8.034
# 7   108   amita    BE  68.33   23      f  8.333
# 9   110   anmol    BE  78.66   21      m  9.366

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
gr['marks'].agg(min)
# Out:
# class
# BE    49.55
# TE    56.75
# Name: marks, dtype: float64

# %%
gr['marks'].agg(max)
# Out:
# class
# BE    78.66
# TE    69.66
# Name: marks, dtype: float64

# %%
import numpy as np

# %%
gr['marks'].agg(np.mean)
# Out:
# class
# BE    67.752
# TE    61.246
# Name: marks, dtype: float64

# %%
df.drop(['gender','cgpa'], axis = 1, inplace= True)

# %%
df
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106   ayesha    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
# create a dataframe
# gender, cgpa, roll column
# roll column will contain same values as 'roll' column of 'df'

# %%
gender = ['m','m','m','m','f','f','m','f','m','m']
cgpa = df['marks'] / 10 + 1.5

# %%
new = pd.DataFrame({
    'roll': range(101,111),
    'gender': gender,
    'cgpa': cgpa
})

# %%
new
# Out:
#    roll gender   cgpa
# 0   101      m  7.177
# 1   102      m  7.477
# 2   103      m  9.188
# 3   104      m  8.466
# 4   105      f  7.828
# 5   106      f  6.455
# 6   107      m  8.034
# 7   108      f  8.333
# 8   109      m  7.175
# 9   110      m  9.366

# %%
df
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106   ayesha    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
pd.merge(df, new, on = 'roll')
# Out:
#    roll     name class  marks  age gender   cgpa
# 0   101     anil    TE  56.77   22      m  7.177
# 1   102     amit    TE  59.77   21      m  7.477
# 2   103   aniket    BE  76.88   19      m  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466
# 4   105     asha    TE  63.28   20      f  7.828
# 5   106   ayesha    BE  49.55   20      f  6.455
# 6   107     amar    BE  65.34   19      m  8.034
# 7   108    amita    BE  68.33   23      f  8.333
# 8   109     amol    TE  56.75   20      m  7.175
# 9   110    anmol    BE  78.66   21      m  9.366

# %%
df
# Out:
#    roll     name class  marks  age
# 0   101     anil    TE  56.77   22
# 1   102     amit    TE  59.77   21
# 2   103   aniket    BE  76.88   19
# 3   104  ajinkya    TE  69.66   20
# 4   105     asha    TE  63.28   20
# 5   106   ayesha    BE  49.55   20
# 6   107     amar    BE  65.34   19
# 7   108    amita    BE  68.33   23
# 8   109     amol    TE  56.75   20
# 9   110    anmol    BE  78.66   21

# %%
newdf = pd.read_csv('student5.csv')
newdf
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
data = pd.concat([df,newdf], ignore_index=True)

# %%
data.to_csv('output.csv', index= False)
